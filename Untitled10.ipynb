# %% [markdown]
# <a href="https://colab.research.google.com/github/lejuvega/proyecto-salud/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/lejuvega/proyecto-salud.git
# Out:
# Cloning into 'proyecto-salud'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (9/9), 2.56 MiB | 3.68 MiB/s, done.

# %%
import pandas as pd

# %%
data = pd.read_excel("/content/proyecto-salud/BASE DE DATOS RCV JUNIO 2022.xlsx")

# %%
data.head(10)
# Out:
#    CONSECUTIVO TIPO DOCUMENTO  NUMERO DE DOCUMENTO  \
# 0          1.0             CC                  1.0
# 1          2.0             CC                  2.0
# 2          3.0             CC                  3.0
# 3          4.0             CC                  4.0
# 4          5.0             CC                  5.0
# 5          6.0             CC                  6.0
# 6          7.0             CC                  7.0
# 7          8.0             CC                  8.0
# 8          9.0             CC                  9.0
# 9         10.0             CC                 10.0
#
#                               Nombre FECHA DE NACIMIENTO  EDAD GENERO  \
# 0        ATENCIA VERGARA JHAN CARLOS          1997-04-22  25.0      M
# 1        JARABA MACHADO MAIRETH NONE          1996-05-17  26.0      F
# 2         RIVERA ARIAS JAIRO ANTONIO          1950-08-24  71.0      M
# 3           RIOS MONTES MARIA ISABEL          1972-08-24  49.0      F
# ...

# %%
data.describe()
# Out:
#        CONSECUTIVO  NUMERO DE DOCUMENTO         EDAD     MUNICIPIO  \
# count  7627.000000          7627.000000  7627.000000   7627.000000
# mean   3814.000000          3814.000000    63.344959  70306.988986
# std    2201.869584          2201.869584    12.642637    293.171089
# min       1.000000             1.000000    11.000000  70001.000000
# 25%    1907.500000          1907.500000    55.000000  70001.000000
# 50%    3814.000000          3814.000000    63.000000  70233.000000
# 75%    5720.500000          5720.500000    73.000000  70670.000000
# max    7627.000000          7627.000000   105.000000  70823.000000
#
#               Peso  TALLA FENIX          IMC           TS           TD  \
# count  7627.000000  7627.000000  7627.000000  7627.000000  7627.000000
# mean     68.279916   158.041694    27.277532   130.462436    78.840566
# std      13.989243     8.293754     4.920066    14.973506     8.538923
# min      25.000000   122.000000    13.150000    80.000000    50.000000
# ...
